# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## variables
# en este apartado veremos como funcionan las variables

# %%
nombre="Oscar"
apellido="Oliva"
print(f"Hola, {nombre} {apellido}!")
# Out:
# Hola, Oscar Oliva!

# %% [markdown]
# ## Variables tipo numericas

# %%
x=10
y=5
suma = x + y
print(f"La suma de {x} y {y} es: {suma}")
# Out:
# La suma de 10 y 5 es: 15
