# %% [markdown]
# # Actividad 1.4
# > Crear una muestra representativa educacional mas limitada del archivo hogares_censo2024.csv y luego ejecutar el ciclo completo: Carga y Exploración, Limpieza (resolviendo faltantes, duplicados y outliers) y Transformación Avanzada (incluyendo normalización, encoding e ingeniería de características).
